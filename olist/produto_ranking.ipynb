# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# Import Feature Engineered Sales Transaction file
df = pd.read_csv('olist_processado.csv')

# %%
df.head(2)
# Out:
#                         customer_id customer_city customer_state  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7        franca             SP
# 1  8912fc0c3bbf1e2fbf35819e21706718      santarem             PA
#
#                            order_id order_purchase_timestamp  order_item_id  \
# 0  00e7ee1b050b8499577073aeb2a297a1      2017-05-16 15:05:35              1
# 1  c1d2b34febe9cd269e378117d6681172      2017-11-09 00:50:13              1
#
#                          product_id   price                         review_id  \
# 0  a9516a079e37a9c9c36b9b78b10169e8  124.99  88b8b52d46df026a9d1ad2136a59b30b
# 1  a9516a079e37a9c9c36b9b78b10169e8  112.99  7fc63200f12eebb5f387856afdd63db8
#
#    review_score  customer_lat  customer_long product_category_name  \
# 0             4    -20.500253     -47.400367     moveis_escritorio
# 1             1     -2.441535     -54.720801     moveis_escritorio
#
#    quantidade_item
# 0                1
# 1                2

# %% [markdown]
# ## Top Categorias Vendidas

# %%
# Encontrando o número de unidades vendidas de cada categoria de produto
top_itens_df = df.groupby(['product_category_name', 'customer_city', 'customer_state']).agg({'quantidade_item':'sum', 'review_score':'max' })

# %%
top_itens_df.reset_index(inplace=True)

# %%
# Rank das categorias mais vendidas
top_itens_df['rank_top_vendidos'] = top_itens_df['review_score'].rank(method='min',ascending=False).astype(int)

# %%
# Lista os top 20 
top_itens_df.sort_values('quantidade_item',ascending=False).head(20)
# Out:
#         product_category_name   customer_city customer_state  quantidade_item  \
# 6559          cama_mesa_banho       sao paulo             SP             3573
# 4162             beleza_saude       sao paulo             SP             2777
# 15805  informatica_acessorios       sao paulo             SP             2325
# 18472        moveis_decoracao       sao paulo             SP             2241
# 25251   utilidades_domesticas       sao paulo             SP             2177
# 12371           esporte_lazer       sao paulo             SP             1780
# 6402          cama_mesa_banho  rio de janeiro             RJ             1254
# 18334        moveis_decoracao  rio de janeiro             RJ             1052
# 22694      relogios_presentes       sao paulo             SP             1044
# 12222           esporte_lazer  rio de janeiro             RJ              902
# 24030               telefonia       sao paulo             SP              871
# 15678  informatica_acessorios  rio de janeiro             RJ              802
# 5138               brinquedos       sao paulo             SP              787
# 25131   utilidades_domesticas  rio de janeiro             RJ              783
# 3993             beleza_saude  rio de janeiro             RJ              759
# 14360      ferramentas_jardim       sao paulo             SP              747
# 1776               automotivo       sao paulo             SP              722
# 20953              perfumaria       sao paulo             SP              709
# 2574                    bebes       sao paulo             SP              614
# 19060       moveis_escritorio       sao paulo             SP              599
#
#        review_score  rank_top_vendidos
# 6559              5                  1
# 4162              5                  1
# 15805             5                  1
# 18472             5                  1
# 25251             5                  1
# 12371             5                  1
# 6402              5                  1
# 18334             5                  1
# 22694             5                  1
# 12222             5                  1
# 24030             5                  1
# 15678             5                  1
# 5138              5                  1
# 25131             5                  1
# 3993              5                  1
# 14360             5                  1
# 1776              5                  1
# 20953             5                  1
# 2574              5                  1
# 19060             5                  1

# %% [markdown]
# ## Top Categorias Populares

# %%
# Remove registros duplicados
pedidos_unicos_df = df.drop_duplicates(['product_category_name','order_purchase_timestamp', 'customer_id'])

# %%
# Encontra o número de pedidos e o número de pedidos únicos de cada categoria
itens_mais_populares_df = pedidos_unicos_df.groupby(['product_category_name', 'customer_city', 'customer_state']).agg({'order_purchase_timestamp':'count', 'customer_id':'nunique'})
itens_mais_populares_df.columns=['no_pedidos', 'no_clientes']

# %%
# Reset o index convertendo o produto em coluna
itens_mais_populares_df.reset_index(inplace=True)

# %%
itens_mais_populares_df.head(2)
# Out:
#        product_category_name customer_city customer_state  no_pedidos  \
# 0  agro_industria_e_comercio  alto piquiri             PR           1
# 1  agro_industria_e_comercio     americana             SP           1
#
#    no_clientes
# 0            1
# 1            1

# %% [markdown]
# ### Categorias de produtos com um número alto de pedidos pode ser considerado os mais frequentes comprados
#
# Para encontrar os itens mais populares, inclua o número de clientes comprados e forneça mais peso às categorias de produtos adquiridas por mais clientes
#
# Ponderação no_pedido (P) = O * (C / M)
#
# O = no_pedidos
#
# C = no_clientes que comprou algo da categoria de produto
#
# M = Nº máximo de clientes que realizaram transações em todo o período

# %%
O = itens_mais_populares_df['no_pedidos']
C = itens_mais_populares_df['no_clientes']
M = itens_mais_populares_df['no_clientes'].max()

# %%
itens_mais_populares_df['no_pedidos_ponderado'] = O * (C / M)

# %%
# Rank de produtos de acordo com o número de pedidos ponderado
itens_mais_populares_df['rank_popularidade'] = itens_mais_populares_df['no_pedidos_ponderado'].rank(method='min',ascending=False).astype(int)

# %%
itens_mais_populares_df.sort_values('rank_popularidade',ascending=True).head(20)
# Out:
#         product_category_name   customer_city customer_state  no_pedidos  \
# 6559          cama_mesa_banho       sao paulo             SP        1653
# 4162             beleza_saude       sao paulo             SP        1533
# 12371           esporte_lazer       sao paulo             SP        1266
# 25251   utilidades_domesticas       sao paulo             SP        1107
# 15805  informatica_acessorios       sao paulo             SP        1004
# 18472        moveis_decoracao       sao paulo             SP         998
# 22694      relogios_presentes       sao paulo             SP         778
# 6402          cama_mesa_banho  rio de janeiro             RJ         726
# 5138               brinquedos       sao paulo             SP         610
# 24030               telefonia       sao paulo             SP         570
# 3993             beleza_saude  rio de janeiro             RJ         523
# 12222           esporte_lazer  rio de janeiro             RJ         513
# 1776               automotivo       sao paulo             SP         501
# 20953              perfumaria       sao paulo             SP         496
# 18334        moveis_decoracao  rio de janeiro             RJ         483
# 15678  informatica_acessorios  rio de janeiro             RJ         462
# 2574                    bebes       sao paulo             SP         456
# 22566      relogios_presentes  rio de janeiro             RJ         436
# 9478               cool_stuff       sao paulo             SP         430
# 25131   utilidades_domesticas  rio de janeiro             RJ         412
#
#        no_clientes  no_pedidos_ponderado  rank_popularidade
# 6559          1653           1653.000000                  1
# 4162          1533           1421.711434                  2
# 12371         1266            969.604356                  3
# 25251         1107            741.348457                  4
# 15805         1004            609.810042                  5
# 18472          998            602.543255                  6
# 22694          778            366.173019                  7
# 6402           726            318.860254                  8
# 5138           610            225.105868                  9
# 24030          570            196.551724                 10
# 3993           523            165.474289                 11
# 12222          513            159.206897                 12
# 1776           501            151.845735                 13
# 20953          496            148.830006                 14
# 18334          483            141.130672                 15
# 15678          462            129.125227                 16
# 2574           456            125.793103                 17
# 22566          436            115.000605                 18
# 9478           430            111.857229                 19
# 25131          412            102.688445                 20

# %%
# Merge dos Ranks de Categoria de produtos mais Vendidos e dos mais Populares
categorias_rankings_df = pd.merge(top_itens_df, itens_mais_populares_df,how='inner',on='product_category_name')

# %%
categorias_rankings_df.columns
# Out:
# Index(['product_category_name', 'customer_city_x', 'customer_state_x',
#        'quantidade_item', 'review_score', 'rank_top_vendidos',
#        'customer_city_y', 'customer_state_y', 'no_pedidos', 'no_clientes',
#        'no_pedidos_ponderado', 'rank_popularidade'],
#       dtype='object')

# %%
categorias_rankings_df = categorias_rankings_df.drop(["customer_city_x", "customer_state_x"], axis=1)

# %%
categorias_rankings_df.columns = [col.replace("_y", "") for col in categorias_rankings_df.columns]

# %%
# Filtra apenas as colunas 'product_category_name','rank_top_vendidos','rank_popularidade', 'customer_city', 'customer_state'
#categorias_rankings_df = categorias_rankings_df[['product_category_name','rank_top_vendidos','rank_popularidade', 'customer_city', 'customer_state']]

# %%
categorias_rankings_df.head()
# Out:
#        product_category_name  quantidade_item  review_score  \
# 0  agro_industria_e_comercio                1             4
# 1  agro_industria_e_comercio                1             4
# 2  agro_industria_e_comercio                1             4
# 3  agro_industria_e_comercio                1             4
# 4  agro_industria_e_comercio                1             4
#
#    rank_top_vendidos customer_city customer_state  no_pedidos  no_clientes  \
# 0              17832  alto piquiri             PR           1            1
# 1              17832     americana             SP           1            1
# 2              17832        amparo             SP           1            1
# 3              17832      andradas             MG           1            1
# 4              17832     andradina             SP           1            1
#
#    no_pedidos_ponderado  rank_popularidade
# 0              0.000605               9567
# 1              0.000605               9567
# 2              0.000605               9567
# 3              0.000605               9567
# 4              0.000605               9567

# %%
# Salva o dataset
categorias_rankings_df.to_csv('rankings_categoria.csv',index=False)

# %%
#Create a Pickle (.pkl) file with the Ranking dataframe
pickle.dump(categorias_rankings_df, open('prod_ranking_modelo.pkl','wb'))
